# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# ### test extract data >>>

# %%
df = pd.read_csv('/Users/zooomx/Documents/zoomcamp_2024/green_tripdata_2019-09.csv', nrows=1000)

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://postgres:postgres@localhost:54399/ny_taxi')

# %%
engine.connect()

# %%
print(pd.io.sql.get_schema(df, name='green_tripdata', con=engine))
# Out:
# CREATE TABLE green_tripdata (
# 	"VendorID" BIGINT,
# 	lpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	lpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	store_and_fwd_flag TEXT,
# 	"RatecodeID" BIGINT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	ehail_fee FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	payment_type BIGINT,
# 	trip_type BIGINT,
# 	congestion_surcharge FLOAT(53)
# )

# %% [markdown]
# ### final code >>>

# %%
df_iter = pd.read_csv('/Users/zooomx/Documents/zoomcamp_2024/green_tripdata_2019-09.csv', iterator=True, chunksize=1000)

# %%
df = next(df_iter)

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
df.head(n=0).to_sql(name='green_tripdata', con=engine, if_exists='replace')  # added name table in database
# Out:
# 0

# %%
# %time df.to_sql(name='green_tripdata', con=engine, if_exists='append')
# Out:
# CPU times: user 108 ms, sys: 30.6 ms, total: 139 ms
# Wall time: 711 ms
# 1000

# %%
from time import time

# %%
while True:
    t_start = time()   
    
    df = next(df_iter)
    
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

    df.to_sql(name='green_tripdata', con=engine, if_exists='append')

    t_end = time()
    print(len(df))
    print('inserted another chunk..., took %.3f second' % (t_end - t_start))
# Out:
# 1000
# inserted another chunk..., took 0.384 second
# 1000
# inserted another chunk..., took 0.284 second
# 1000
# inserted another chunk..., took 0.278 second
# 1000
# inserted another chunk..., took 0.254 second
# 1000
# inserted another chunk..., took 0.273 second
# 1000
# inserted another chunk..., took 0.269 second
# 1000
# inserted another chunk..., took 0.265 second
# 1000
# inserted another chunk..., took 1.313 second
# 1000
# inserted another chunk..., took 0.258 second
# 1000
# inserted another chunk..., took 0.262 second
# 1000
# inserted another chunk..., took 0.269 second
# 1000
# inserted another chunk..., took 0.275 second
# 1000
# inserted another chunk..., took 0.259 second
# 1000
# inserted another chunk..., took 0.263 second
# 1000
# inserted another chunk..., took 0.345 second
# 1000
# inserted another chunk..., took 1.130 second
# 1000
# inserted another chunk..., took 0.697 second
# 1000
# inserted another chunk..., took 0.637 second
# 1000
# ...

# %% [markdown]
# #### All rows  were addited to postgres 'green_tripdata'

# %%
df = pd.read_csv('/Users/zooomx/Documents/zoomcamp_2024/taxi+_zone_lookup.csv', nrows=10)

# %%
print(pd.io.sql.get_schema(df, name='taxi_zone_lookup', con=engine))
# Out:
# CREATE TABLE taxi_zone_lookup (
# 	"LocationID" BIGINT,
# 	"Borough" TEXT,
# 	"Zone" TEXT,
# 	service_zone TEXT
# )

# %%
print(len(df))
# Out:
# 265

# %%
df_iter = pd.read_csv('/Users/zooomx/Documents/zoomcamp_2024/taxi+_zone_lookup.csv', iterator=True, chunksize=10000)

# %%
df = next(df_iter)

# %%
df.head(n=0).to_sql(name='taxi_zone_lookup', con=engine, if_exists='replace')  # added name table in database
# Out:
# 0

# %%
# %time df.to_sql(name='taxi_zone_lookup', con=engine, if_exists='append')
# Out:
# CPU times: user 14.8 ms, sys: 18 ms, total: 32.8 ms
# Wall time: 169 ms
# 265

# %% [markdown]
# #### All rows  were addited to postgres 'taxi_zone_lookup'
